# %%
pip freeze
# Out:
# aiohttp @ file:///tmp/build/80754af9/aiohttp_1632748407387/work
# anyio @ file:///home/conda/feedstock_root/build_artifacts/anyio_1641898027206/work/dist
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# asn1crypto==1.4.0
# asttokens==2.0.5
# async-timeout==3.0.1
# attrs @ file:///home/conda/feedstock_root/build_artifacts/attrs_1640799537051/work
# Automat==20.2.0
# azure-common==1.1.27
# azure-core==1.17.0
# azure-storage-blob==12.8.1
# Babel @ file:///home/conda/feedstock_root/build_artifacts/babel_1619719576210/work
# backcall==0.2.0
# backoff==1.11.1
# backports.functools-lru-cache @ file:///home/conda/feedstock_root/build_artifacts/backports.functools_lru_cache_1618230623929/work
# beautifulsoup4==4.10.0
# black==22.1.0
# bleach==4.1.0
# boto3==1.18.27
# botocore==1.21.27
# Brotli==1.0.9
# brotlipy==0.7.0
# bs4==0.0.1
# cairocffi==1.3.0
# certifi==2021.10.8
# cffi==1.14.6
# chardet==3.0.4
# ...
